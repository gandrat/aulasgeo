# %% [markdown]
# <a href="https://colab.research.google.com/github/gandrat/aulasgeo/blob/main/RBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Tipos de Dados em R
# - Numeric
# - Integer
# - Character
# - Logical
# - Factor
#
# ## Tipos de Estruturas em R
# Antes de começarmos a lidar com dados, é importante esclarecer os principais tipos de dados e estruturas em R. De uma forma simplicada, estes serão os tipos de dados mais utilizados em R:
#
# - Vectors
# - Lists
# - Matrices
# - Arrays
# - Factors
# - Data Frames

# %% [markdown]
# #Bibliotecas
#
# ## Instalando pacotes
# Você só precisará rodar este pedaço de código da primeira vez que for utilizar este Colab. Caso você esteja utilizando o R e RStudio instalado no seu computador, também só precisará rodar da primeira vez.

# %%
#Install packages outside R (On Linux)
system('sudo apt-get install libudunits2-dev libgdal-dev libgeos-dev libproj-dev')

#Install packages (only first time)
require("ggplot2") #Gráficos lindos e customizáveis
require("dplyr") #Uma boa forma de manipulação de dados
require("sf") #Lidando com dados espaciais de forma simples e direta

# %% [markdown]
# ## Carregando pacotes
# Isto deverá ser rodado todas as vezes que você for utilizar o script.

# %%
#Load packages (everytime)
library(ggplot2)
library(dplyr)
library(sf)

# %% [markdown]
# # Carregando dados
#
# Neste curso, utilizaremos dados municipais sociodemográficos (tabela muni) e dados semanais de evolução da COVID para estes municípios (tabela cv).
#
# Estes dados foram preparados anteriormente e salvos em um arquivo de dados do R (.Rda). Dentro deste arquivo,

# %%
#Loading data
load('cv.Rda')

#List tables
ls()
plot(muni_sf)
# Out:
# [1] "cv"      "muni"    "muni_sf" "rgi"
# Plot with title “nome_rgi”
